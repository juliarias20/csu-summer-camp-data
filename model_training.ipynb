# %%
import pandas as pd
df = pd.read_csv('october_data.csv')

# %%
# Select columns containing the specified keywords
keywords = [
    'mental health', 'Counseling and Psychological Services', 'avoid conflict or confrontation',
    'Feeling a sense of belonging', 'room switch request', 'job', 'Internships',
    'advice from my parents or family', 'Roommate conflicts', 'Eat at an on campus eatery',
    'Eat with friends', 'Eat alone', 'Prepared a meal on my own'
]

# Find columns that contain any of the keywords (case-insensitive)
cols = [col for col in df.columns if any(kw.lower() in col.lower() for kw in keywords)]

# Output the selected information
df[cols]
# Out:
#     I seek advice from my parents or family  \
# 0                                     Agree
# 1                                   Neutral
# 2                            Did not answer
# 3                            Did not answer
# 4                                     Agree
# ..                                      ...
# 757                                   Agree
# 758                                   Agree
# 759                          Did not answer
# 760                                 Neutral
# 761                                   Agree
#
#     I have submitted a room switch request due to a roommate conflict  \
# 0                                             Disagree
# 1                                             Disagree
# 2                                       Did not answer
# 3                                       Did not answer
# 4                                             Disagree
# ..                                                 ...
# 757                                           Disagree
# 758                                           Disagree
# 759                                     Did not answer
# 760                                           Disagree
# 761                                              Agree
#
#     I avoid conflict or confrontation, so I don't address the issue.  \
# 0                                             Disagree
# 1                                              Neutral
# 2                                       Did not answer
# 3                                       Did not answer
# 4                                             Disagree
# ..                                                 ...
# 757                                            Neutral
# 758                                           Disagree
# 759                                     Did not answer
# 760                                              Agree
# 761                                           Disagree
#
#     Feeling a sense of belonging within the university community (Sense of belonging is the feeling that we have satisfied our emotional need to belong to a community or group because we feel accepted, included, respected, and supported by a group)  \
# 0                                                Agree
# 1                                              Neutral
# 2                                                Agree
# 3                                                Agree
# 4                                              Neutral
# ..                                                 ...
# 757                                           Disagree
# 758                                              Agree
# 759                                              Agree
# 760                                              Agree
# 761                                              Agree
#
#     Worked a job on campus Worked a job off campus  \
# 0                       No                      No
# 1                       No                      No
# 2                      Yes          Not Applicable
# 3                      Yes          Not Applicable
# 4                       No                      No
# ..                     ...                     ...
# 757                     No                      No
# 758                     No                      No
# 759                     No                      No
# 760                     No                      No
# 761                     No                      No
#
#     Eat at an on campus eatery (Food trucks, restaurants, food court)  \
# 0                                   More than 10 Times
# 1                                           6-10 Times
# 2                                   More than 10 Times
# 3                                   More than 10 Times
# 4                                           6-10 Times
# ..                                                 ...
# 757                                          1-5 Times
# 758                                 More than 10 Times
# 759                                 More than 10 Times
# 760                                 More than 10 Times
# 761                                 More than 10 Times
#
#     Prepared a meal on my own    Eat with friends           Eat alone  \
# 0          More than 10 Times  More than 10 Times  More than 10 Times
# 1                  6-10 Times           1-5 Times             0 Times
# 2                  6-10 Times  More than 10 Times  More than 10 Times
# 3                   1-5 Times  More than 10 Times  More than 10 Times
# 4                  6-10 Times          6-10 Times          6-10 Times
# ..                        ...                 ...                 ...
# 757                 1-5 Times          6-10 Times           1-5 Times
# 758                 1-5 Times  More than 10 Times             0 Times
# 759        More than 10 Times  More than 10 Times          6-10 Times
# 760                   0 Times          6-10 Times           1-5 Times
# 761                 1-5 Times  More than 10 Times           1-5 Times
#
#     How would you rate your mental health during the last 30 days?  \
# 0                                                 Good
# 1                                                 Poor
# 2                                              Neutral
# 3                                                 Good
# 4                                              Neutral
# ..                                                 ...
# 757                                            Neutral
# 758                                          Excellent
# 759                                               Good
# 760                                          Excellent
# 761                                          Excellent
#
#     Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?
# 0                                       Did not answer
# 1                                  Not yet but i might
# 2                                       Did not answer
# 3                                       Did not answer
# 4                                       Did not answer
# ..                                                 ...
# 757                                     Did not answer
# 758                                     Did not answer
# 759                                     Did not answer
# 760                                     Did not answer
# 761                                     Did not answer
#
# [762 rows x 12 columns]

# %%
# Install scikit-learn if needed
# No need to install scikit-learn again, as it is already imported in a later cell

# Define the columns to use based on the provided text
selected_keywords = [
    'Eat at an on campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone',
    'how confident are you in preparing a nutritious, healthy meal for yourself?',
    'Worked a job on campus',
    'Worked a job off campus',
    'Participated in an internship off campus',
    'Participated in an internship on campus',
    'Participated in undergraduate research',
    'How would you rate your mental health during the last 30 days?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?',
    "I avoid conflict or confrontation, so I don't address the issue.",
    'Feeling a sense of belonging within the university community',
    'I have submitted a room switch request due to a roommate conflict'
]

# Find columns that contain any of the selected keywords (case-insensitive)
cols = [col for col in df.columns if any(kw.lower() in col.lower() for kw in selected_keywords)]

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Define your target column
target_col = 'How would you rate your mental health during the last 30 days?'

# Define the columns you want to use, including the target column
# Example: cols = ['Age', 'Gender', 'Sleep Quality', ..., target_col]
if target_col not in cols:
    raise ValueError(f"Target column '{target_col}' not found in selected columns.")

# Prepare feature matrix X and target vector y
X = df[[col for col in cols if col != target_col]].copy()
y = df[target_col].copy()

# Encode categorical variables
le_dict = {}
for col in X.columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
    le_dict[col] = le  # optional: store encoders for inverse_transform later

# Encode target
target_le = LabelEncoder()
y_encoded = target_le.fit_transform(y.astype(str))

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train the model
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# (Optional) Evaluate performance
accuracy = clf.score(X_test, y_test)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.45

# %%
# Show actual vs predicted values for the test set
results = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})
print(results.head(10))

# Show model accuracy
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
#    Actual  Predicted
# 0       2   2.076527
# 1       3   2.761419
# 2       2   2.301121
# 3       5   3.681999
# 4       2   1.978643
# 5       4   4.053195
# 6       1   2.028019
# 7       3   2.149380
# 8       4   5.131631
# 9       2   2.233695
# Model Accuracy: 0.45

# %%
# Install scikit-learn if needed
# No need to install scikit-learn again, as it is already imported in a later cell

# Define the columns to use based on the provided text
selected_keywords = [
    'Eat at an on campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone',
    'how confident are you in preparing a nutritious, healthy meal for yourself?',
    'Worked a job on campus',
    'Worked a job off campus',
    'Participated in an internship off campus',
    'Participated in an internship on campus',
    'Participated in undergraduate research',
    'How would you rate your mental health during the last 30 days?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?',
    "I avoid conflict or confrontation, so I don't address the issue.",
    'Feeling a sense of belonging within the university community',
    'I have submitted a room switch request due to a roommate conflict'
]

# Find columns that contain any of the selected keywords (case-insensitive)
cols = [col for col in df.columns if any(kw.lower() in col.lower() for kw in selected_keywords)]

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Define your target column
target_col = 'How would you rate your mental health during the last 30 days?'

# Define the columns you want to use, including the target column
# Example: cols = ['Age', 'Gender', 'Sleep Quality', ..., target_col]
if target_col not in cols:
    raise ValueError(f"Target column '{target_col}' not found in selected columns.")

# Prepare feature matrix X and target vector y
X = df[[col for col in cols if col != target_col]].copy()
y = df[target_col].copy()

# Encode categorical variables
le_dict = {}
for col in X.columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
    le_dict[col] = le  # optional: store encoders for inverse_transform later

# Encode target
target_le = LabelEncoder()
y_encoded = target_le.fit_transform(y.astype(str))

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train the model
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# (Optional) Evaluate performance
accuracy = clf.score(X_test, y_test)
print(f"Model Accuracy: {accuracy:.2f}")

# %%
# Define the columns based on the provided list (case-insensitive match)
column_keywords = [
    'Eat at an on campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone',
    'How confident are you in preparing a nutritious, healthy meal for yourself?',
    'Working a job on campus',
    'Working a job off campus',
    'Participating in an internship off campus',
    'Participating in an internship on campus',
    'Participating in undergraduate research',
    'How would you rate your mental health during the past 30 days?',
    'Have you reached out to Counseling and Psychological Services',
    'I avoid conflict or confrontation, so I don\'t always report issues',
    'Feeling a sense of belonging within the university community',
    'I have submitted a room switch request due to conflict',
    'My roommate(s) and I do not have any conflicts',
    'I avoid conflict or confrontation, so I don’t address the issue.',
    'I have submitted a room switch request due to a roommate conflict',
    'I seek assistance from my residence hall coordinator (RHC)',
    'I seek assistance from my student leader (RA or CA)',
    'I use the Shared Living Agreement to guide discussion/conversation',
    'I seek advice from my parents or family',
    'I initiate open communication and discussion',
    'In the last 30 days, how would you describe your relationship with your roommate(s)?',
    'How many total people live in your suite or apartment unit?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?'
]

# Find columns in df that match any of the keywords (case-insensitive)
cols = [col for col in df.columns if any(kw.lower() in col.lower() for kw in column_keywords)]
print(cols)
# Out:
# ['How many total people live in your suite or apartment unit?', 'In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice', 'I initiate open communication and discussion', 'I seek advice from my parents or family', 'I use the Shared Living Agreement to guide discussion/conversation', 'I seek assistance from my student leader (RA or CA)', 'I seek assistance from my residence hall coordinator (RHC)', 'I have submitted a room switch request due to a roommate conflict', 'My roommate(s) and I do not have any conflicts', 'Feeling a sense of belonging within the university community (Sense of belonging is the feeling that we have satisfied our emotional need to belong to a community or group because we feel accepted, included, respected, and supported by a group)', 'Eat at an on campus eatery (Food trucks, restaurants, food court)', 'Prepared a meal on my own', 'Eat with friends', 'Eat alone', 'how confident are you in preparing a nutritious, healthy meal for yourself?', 'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Fit linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")

# Calculate model accuracy by rounding predictions to nearest integer and comparing to actual
accuracy = (y_test == y_pred.round().astype(int)).mean()
print(f"Model Accuracy: {accuracy:.2f}")

# Show actual vs predicted values
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results.head(10))
# Out:
# Mean Squared Error: 0.5528
# R^2 Score: 0.3482
# Model Accuracy: 0.55
#    Actual  Predicted
# 0       2   2.060903
# 1       3   2.797861
# 2       2   2.305420
# 3       5   3.704030
# 4       2   2.081996
# 5       4   4.111297
# 6       1   1.975407
# 7       3   2.088862
# 8       4   5.296403
# 9       2   2.167078

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Redefine the columns to check (matching actual dataframe columns)
columns_to_check = [
    'Eat at an on campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone',
    'how confident are you in preparing a nutritious, healthy meal for yourself?',
    'Worked a job on campus',
    'Worked a job off campus',
    'Participated in an internship off campus',
    'Participated in an internship on campus',
    'Participated in undergraduate research',
    'How would you rate your mental health during the last 30 days?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?',
    "I avoid conflict or confrontation, so I don't address the issue.",
    'Feeling a sense of belonging within the university community',
    'I have submitted a room switch request due to conflict',
    'My roommate(s) and I do not have any conflicts',
    'I have submitted a room switch request due to a roommate conflict',
    'I seek assistance from my residence hall coordinator (RHC)',
    'I seek assistance from my student leader (RA or CA)',
    'I use the Shared Living Agreement to guide discussion/conversation',
    'I seek advice from my parents or family',
    'I initiate open communication and discussion',
    'In the last 30 days, how would you describe your relationship with your roommate(s)?',
    'How many total people live in your suite or apartment unit?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?'
]

# Filter columns that exist in the dataframe
existing_columns = [col for col in columns_to_check if col in df.columns]

# Prepare the feature matrix and target
target_col = 'How would you rate your mental health during the last 30 days?'
if target_col not in existing_columns:
    raise ValueError(f"Target column '{target_col}' not found in selected columns.")

X = df[[col for col in existing_columns if col != target_col]].copy()
y = df[target_col].copy()

# Encode categorical variables
le_dict = {}
for col in X.columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
    le_dict[col] = le

# Encode target
target_le = LabelEncoder()
y_encoded = target_le.fit_transform(y.astype(str))

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Evaluate performance
accuracy = clf.score(X_test, y_test)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 49
#      47 for col in X.columns:
#      48     le = LabelEncoder()
# ---> 49     X[col] = le.fit_transform(X[col].astype(str))
#      50     le_dict[col] = le
#      52 # Encode target
#
# File ~/csu-summer-camp-data/.venv/lib64/python3.9/site-packages/sklearn/preprocessing/_label.py:110, in LabelEncoder.fit_transform(self, y)
#      97 def fit_transform(self, y):
#      98     """Fit label encoder and return encoded labels.
#      99
#     100     Parameters
#    (...)
#     108         Encoded labels.
#     109     """
# --> 110     y = column_or_1d(y, warn=True)
#     111     self.classes_, y = _unique(y, return_inverse=True)
#     112     return y
#
# File ~/csu-summer-camp-data/.venv/lib64/python3.9/site-packages/sklearn/utils/validation.py:1485, in column_or_1d(y, dtype, warn, device)
#    1472         warnings.warn(
#    1473             (
#    1474                 "A column-vector y was passed when a 1d array was"
#    (...)
#    1479             stacklevel=2,
#    1480         )
#    1481     return _asarray_with_order(
#    1482         xp.reshape(y, (-1,)), order="C", xp=xp, device=device
#    1483     )
# -> 1485 raise ValueError(
#    1486     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1487 )
#
# ValueError: y should be a 1d array, got an array of shape (762, 2) instead.

# %%
X.shape
# Out:
# (762, 21)

# %%
X_train.shape
# Out:
# (609, 14)

# %%
# Define the columns we want to check (matching actual dataframe columns)
columns_to_check = [
    'Eat at an on campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone',
    'how confident are you in preparing a nutritious, healthy meal for yourself?',
    'Worked a job on campus',
    'Worked a job off campus',
    'Participated in an internship off campus',
    'Participated in an internship on campus',
    'Participated in undergraduate research',
    'How would you rate your mental health during the last 30 days?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?',
    "I avoid conflict or confrontation, so I don't address the issue.",
    'Feeling a sense of belonging within the university community',
    'I have submitted a room switch request due to conflict',
    'My roommate(s) and I do not have any conflicts',
    'I have submitted a room switch request due to a roommate conflict',
    'I seek assistance from my residence hall coordinator (RHC)',
    'I seek assistance from my student leader (RA or CA)',
    'I use the Shared Living Agreement to guide discussion/conversation',
    'I seek advice from my parents or family',
    'I initiate open communication and discussion',
    'In the last 30 days, how would you describe your relationship with your roommate(s)?',
    'How many total people live in your suite or apartment unit?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?'
]

# Filter columns that exist in the dataframe
existing_columns = [col for col in columns_to_check if col in df.columns]
print(existing_columns)
# Out:
# ['Eat at an on campus eatery (Food trucks, restaurants, food court)', 'Prepared a meal on my own', 'Eat with friends', 'Eat alone', 'how confident are you in preparing a nutritious, healthy meal for yourself?', 'Worked a job on campus', 'Worked a job off campus', 'Participated in an internship off campus', 'Participated in an internship on campus', 'Participated in undergraduate research', 'How would you rate your mental health during the last 30 days?', 'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?', "I avoid conflict or confrontation, so I don't address the issue.", 'My roommate(s) and I do not have any conflicts', 'I have submitted a room switch request due to a roommate conflict', 'I seek assistance from my residence hall coordinator (RHC)', 'I seek assistance from my student leader (RA or CA)', 'I use the Shared Living Agreement to guide discussion/conversation', 'I seek advice from my parents or family', 'I initiate open communication and discussion', 'How many total people live in your suite or apartment unit?', 'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Redefine the columns for features and target based on X_train and y_train
# X_train is already prepared and y_train is already encoded

# Fit linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.4f}")
print(f"R^2 Score: {r2:.4f}")

# Calculate model accuracy by rounding predictions to nearest integer and comparing to actual
accuracy = (y_test == y_pred.round().astype(int)).mean()
print(f"Model Accuracy: {accuracy:.2f}")

# Show actual vs predicted values
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results.head(10))
# Out:
# Mean Squared Error: 0.5528
# R^2 Score: 0.3482
# Model Accuracy: 0.55
#    Actual  Predicted
# 0       2   2.060903
# 1       3   2.797861
# 2       2   2.305420
# 3       5   3.704030
# 4       2   2.081996
# 5       4   4.111297
# 6       1   1.975407
# 7       3   2.088862
# 8       4   5.296403
# 9       2   2.167078

# %%
# Define the columns we want to check (matching actual dataframe columns)
columns_to_check = [
    'Eat at an on campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone',
    'how confident are you in preparing a nutritious, healthy meal for yourself?',
    'Worked a job on campus',
    'Worked a job off campus',
    'Participated in an internship off campus',
    'Participated in an internship on campus',
    'Participated in undergraduate research',
    'How would you rate your mental health during the last 30 days?',
    'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?',
    "I avoid conflict or confrontation, so I don't address the issue.",
    'Feeling a sense of belonging within the university community (Sense of belonging is the feeling that we have satisfied our emotional need to belong to a community or group because we feel accepted, included, respected, and supported by a group)',
    'My roommate(s) and I do not have any conflicts',
    'I have submitted a room switch request due to a roommate conflict',
    'I seek assistance from my residence hall coordinator (RHC)',
    'I seek assistance from my student leader (RA or CA)',
    'I use the Shared Living Agreement to guide discussion/conversation',
    'I seek advice from my parents or family',
    'I initiate open communication and discussion',
    'In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice',
    'How many total people live in your suite or apartment unit?',
    'Have you reached out to Well-being & Health Promotion for nutritional resources? If not, why not?'
]

# Filter columns that exist in the dataframe
existing_columns = [col for col in columns_to_check if col in df.columns]
print(existing_columns)
# Out:
# ['Eat at an on campus eatery (Food trucks, restaurants, food court)', 'Prepared a meal on my own', 'Eat with friends', 'Eat alone', 'how confident are you in preparing a nutritious, healthy meal for yourself?', 'Worked a job on campus', 'Worked a job off campus', 'Participated in an internship off campus', 'Participated in an internship on campus', 'Participated in undergraduate research', 'How would you rate your mental health during the last 30 days?', 'Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not?', "I avoid conflict or confrontation, so I don't address the issue.", 'Feeling a sense of belonging within the university community (Sense of belonging is the feeling that we have satisfied our emotional need to belong to a community or group because we feel accepted, included, respected, and supported by a group)', 'My roommate(s) and I do not have any conflicts', 'I have submitted a room switch request due to a roommate conflict', 'I seek assistance from my residence hall coordinator (RHC)', 'I seek assistance from my student leader (RA or CA)', 'I use the Shared Living Agreement to guide discussion/conversation', 'I seek advice from my parents or family', 'I initiate open communication and discussion', 'In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice', 'How many total people live in your suite or apartment unit?', 'Have you reached out to Well-being & Health Promotion for nutritional resources? If not, why not?']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error, r2_score

# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
# For accuracy, round predictions to nearest integer and compare to actual
lr_accuracy = (y_test == y_pred_lr.round().astype(int)).mean()

print("Linear Regression Results:")
print(f"Model Accuracy: {lr_accuracy:.2f}")
print("Actual vs Predicted (first 10 rows):")
print(pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr}).head(10))

# Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
y_pred_tree = clf.predict(X_test)
tree_accuracy = (y_test == y_pred_tree).mean()

print("\nDecision Tree Results:")
print(f"Model Accuracy: {tree_accuracy:.2f}")
print("Actual vs Predicted (first 10 rows):")
print(pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_tree}).head(10))
# Out:
# Linear Regression Results:
# Model Accuracy: 0.55
# Actual vs Predicted (first 10 rows):
#    Actual  Predicted
# 0       2   2.060903
# 1       3   2.797861
# 2       2   2.305420
# 3       5   3.704030
# 4       2   2.081996
# 5       4   4.111297
# 6       1   1.975407
# 7       3   2.088862
# 8       4   5.296403
# 9       2   2.167078
#
# Decision Tree Results:
# Model Accuracy: 0.45
# Actual vs Predicted (first 10 rows):
#    Actual  Predicted
# 0       2          3
# 1       3          3
# 2       2          2
# 3       5          5
# 4       2          1
# 5       4          4
# 6       1          2
# 7       3          2
# 8       4          4
# 9       2          2

# %%
X_test.shape
# Out:
# (153, 14)

# %%
# Install and import required packages for machine learning
# %pip install scikit-learn matplotlib seaborn numpy

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

print("✅ Packages installed and imported successfully!")
# Out:
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.9/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 21.3.1; however, version 25.2 is available.
# You should consider upgrading via the '/home/ec2-user/csu-summer-camp-data/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ✅ Packages installed and imported successfully!

# %%
# Data Preprocessing Functions
print("🔧 DATA PREPROCESSING SETUP")
print("=" * 80)

def preprocess_features(df, feature_columns):
    """
    Preprocess the feature columns for machine learning
    """
    # Create a copy of the data with only our feature columns
    X = df[feature_columns].copy()
    
    print(f"Original feature matrix shape: {X.shape}")
    
    # Check for missing values
    missing_counts = X.isnull().sum()
    missing_columns = missing_counts[missing_counts > 0]
    
    if len(missing_columns) > 0:
        print(f"\n⚠️  Missing values found:")
        for col, count in missing_columns.items():
            print(f"  - {col}: {count} missing values")
        
        # Handle missing values (fill with median for numeric, mode for categorical)
        for col in missing_columns.index:
            if X[col].dtype in ['int64', 'float64']:
                X[col].fillna(X[col].median(), inplace=True)
            else:
                X[col].fillna(X[col].mode()[0], inplace=True)
        print("✅ Missing values handled")
    else:
        print("✅ No missing values found")
    
    # Encode categorical variables
    categorical_columns = X.select_dtypes(include=['object']).columns
    numerical_columns = X.select_dtypes(include=['int64', 'float64']).columns
    
    print(f"\nCategorical columns: {len(categorical_columns)}")
    print(f"Numerical columns: {len(numerical_columns)}")
    
    # Label encode categorical variables
    label_encoders = {}
    for col in categorical_columns:
        le = LabelEncoder()
        X[col] = le.fit_transform(X[col].astype(str))
        label_encoders[col] = le
        print(f"  Encoded: {col} ({X[col].nunique()} unique values)")
    
    # Scale numerical features
    scaler = StandardScaler()
    if len(numerical_columns) > 0:
        X[numerical_columns] = scaler.fit_transform(X[numerical_columns])
        print(f"✅ Scaled {len(numerical_columns)} numerical columns")
    
    print(f"\nFinal feature matrix shape: {X.shape}")
    return X, label_encoders, scaler

# Preview the preprocessing on our 24 columns
print(f"\n🔍 PREPROCESSING PREVIEW:")
print("-" * 50)
X_processed, encoders, scaler = preprocess_features(df, columns_to_check)

print(f"\n📊 FEATURE STATISTICS:")
print("-" * 30)
print(X_processed.describe())
# Out:
# 🔧 DATA PREPROCESSING SETUP
# ================================================================================
#
# 🔍 PREPROCESSING PREVIEW:
# --------------------------------------------------
# Original feature matrix shape: (762, 24)
#
# ⚠️  Missing values found:
#   - how confident are you in preparing a nutritious, healthy meal for yourself?: 1 missing values
# ✅ Missing values handled
#
# Categorical columns: 23
# Numerical columns: 1
#   Encoded: Eat at an on campus eatery (Food trucks, restaurants, food court) (5 unique values)
#   Encoded: Prepared a meal on my own (5 unique values)
#   Encoded: Eat with friends (5 unique values)
#   Encoded: Eat alone (5 unique values)
#   Encoded: Worked a job on campus (4 unique values)
#   Encoded: Worked a job off campus (4 unique values)
#   Encoded: Participated in an internship off campus (4 unique values)
#   Encoded: Participated in an internship on campus (4 unique values)
#   Encoded: Participated in undergraduate research (4 unique values)
#   Encoded: How would you rate your mental health during the last 30 days? (6 unique values)
#   Encoded: Have you reached out to SDSU Counseling and Psychological Services for mental health resources? If not, why not? (83 unique values)
#   Encoded: I avoid conflict or confrontation, so I don't address the issue. (4 unique values)
#   Encoded: Feeling a sense of belonging within the university community (Sense of belonging is the feeling that we have satisfied our emotional need to belong to a community or group because we feel accepted, included, respected, and supported by a group) (4 unique values)
#   Encoded: My roommate(s) and I do not have any conflicts (4 unique values)
#   Encoded: I have submitted a room switch request due to a roommate conflict (4 unique values)
#   Encoded: I seek assistance from my residence hall coordinator (RHC) (4 unique values)
#   Encoded: I seek assistance from my student leader (RA or CA) (4 unique values)
#   Encoded: I use the Shared Living Agreement to guide discussion/conversation (4 unique values)
#   Encoded: I seek advice from my parents or family (4 unique values)
#   Encoded: I initiate open communication and discussion (4 unique values)
#   Encoded: In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice (5 unique values)
#   Encoded: How many total people live in your suite or apartment unit? (6 unique values)
#   Encoded: Have you reached out to Well-being & Health Promotion for nutritional resources? If not, why not? (127 unique values)
# ✅ Scaled 1 numerical columns
#
# Final feature matrix shape: (762, 24)
#
# 📊 FEATURE STATISTICS:
# ------------------------------
#        Eat at an on campus eatery (Food trucks, restaurants, food court)  \
# count                                         762.000000
# mean                                            2.914698
# std                                             1.499652
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             4.000000
#
#        Prepared a meal on my own  Eat with friends   Eat alone  \
# count                 762.000000        762.000000  762.000000
# mean                    1.880577          2.723097    2.523622
# std                     1.462691          1.392949    1.411458
# min                     0.000000          0.000000    0.000000
# 25%                     1.000000          1.000000    1.000000
# 50%                     1.000000          4.000000    2.000000
# 75%                     4.000000          4.000000    4.000000
# max                     4.000000          4.000000    4.000000
#
#        how confident are you in preparing a nutritious, healthy meal for yourself?  \
# count                                       7.620000e+02
# mean                                       -2.797412e-17
# std                                         1.000657e+00
# min                                        -2.385482e+00
# 25%                                        -5.998854e-01
# 50%                                         2.929128e-01
# 75%                                         1.185711e+00
# max                                         1.185711e+00
#
#        Worked a job on campus  Worked a job off campus  \
# count              762.000000               762.000000
# mean                 1.317585                 1.217848
# std                  0.729647                 0.615009
# min                  0.000000                 0.000000
# 25%                  1.000000                 1.000000
# 50%                  1.000000                 1.000000
# 75%                  1.000000                 1.000000
# max                  3.000000                 3.000000
#
#        Participated in an internship off campus  \
# count                                762.000000
# mean                                   1.080052
# std                                    0.359070
# min                                    0.000000
# 25%                                    1.000000
# 50%                                    1.000000
# 75%                                    1.000000
# max                                    3.000000
#
#        Participated in an internship on campus  \
# count                               762.000000
# mean                                  1.074803
# std                                   0.352830
# min                                   0.000000
# 25%                                   1.000000
# 50%                                   1.000000
# 75%                                   1.000000
# max                                   3.000000
#
#        Participated in undergraduate research  ...  \
# count                              762.000000  ...
# mean                                 1.192913  ...
# std                                  0.573898  ...
# min                                  0.000000  ...
# 25%                                  1.000000  ...
# 50%                                  1.000000  ...
# 75%                                  1.000000  ...
# max                                  3.000000  ...
#
#        My roommate(s) and I do not have any conflicts  \
# count                                      762.000000
# mean                                         1.125984
# std                                          1.312983
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          3.000000
# max                                          3.000000
#
#        I have submitted a room switch request due to a roommate conflict  \
# count                                         762.000000
# mean                                            1.872703
# std                                             0.600758
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             3.000000
#
#        I seek assistance from my residence hall coordinator (RHC)  \
# count                                         762.000000
# mean                                            1.940945
# std                                             1.031910
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        I seek assistance from my student leader (RA or CA)  \
# count                                         762.000000
# mean                                            1.547244
# std                                             1.262415
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        I use the Shared Living Agreement to guide discussion/conversation  \
# count                                         762.000000
# mean                                            1.484252
# std                                             1.288946
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        I seek advice from my parents or family  \
# count                               762.000000
# mean                                  0.816273
# std                                   1.205702
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   2.000000
# max                                   3.000000
#
#        I initiate open communication and discussion  \
# count                                    762.000000
# mean                                       0.576115
# std                                        1.099567
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        3.000000
#
#        In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice  \
# count                                         762.000000
# mean                                            2.570866
# std                                             0.959545
# min                                             0.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        How many total people live in your suite or apartment unit?  \
# count                                         762.000000
# mean                                            2.125984
# std                                             1.191244
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Have you reached out to Well-being & Health Promotion for nutritional resources? If not, why not?
# count                                         762.000000
# mean                                           11.859580
# std                                            28.180337
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                           126.000000
#
# [8 rows x 24 columns]

# %%
# Create Demo Target Variables (Replace this with your actual target)
print("🎯 TARGET VARIABLE SETUP")
print("=" * 80)

print("Since no target variable was specified, I'll create demo targets for illustration.")
print("Please replace this section with your actual target variable!\n")

# Create a synthetic binary target for classification (at-risk students)
# This is just for demonstration - replace with your actual target
np.random.seed(42)  # For reproducibility

# Create a binary target based on some logical rules (just for demo)
# You should replace this with your actual target column
mental_health_col = 'How would you rate your mental health during the last 30 days?'

# Create demo binary target (0 = not at risk, 1 = at risk)
# This is completely artificial - use your real target!
y_binary = np.random.choice([0, 1], size=len(df), p=[0.7, 0.3])

# Create demo continuous target (GPA-like score)
# This is completely artificial - use your real target!
y_continuous = np.random.normal(3.0, 0.8, len(df))
y_continuous = np.clip(y_continuous, 0, 4)  # Clip to 0-4 range like GPA

print(f"✅ Demo binary target created (classification): {len(y_binary)} samples")
print(f"   - Class 0 (not at-risk): {sum(y_binary == 0)} students ({sum(y_binary == 0)/len(y_binary)*100:.1f}%)")
print(f"   - Class 1 (at-risk): {sum(y_binary == 1)} students ({sum(y_binary == 1)/len(y_binary)*100:.1f}%)")

print(f"\n✅ Demo continuous target created (regression): {len(y_continuous)} samples")
print(f"   - Mean: {np.mean(y_continuous):.3f}")
print(f"   - Std: {np.std(y_continuous):.3f}")
print(f"   - Range: [{np.min(y_continuous):.3f}, {np.max(y_continuous):.3f}]")

print("\n" + "="*50)
print("🚨 IMPORTANT: Replace the above with your actual target variable!")
print("   Example: y_actual = df['your_target_column_name']")
print("="*50)
# Out:
# 🎯 TARGET VARIABLE SETUP
# ================================================================================
# Since no target variable was specified, I'll create demo targets for illustration.
# Please replace this section with your actual target variable!
#
# ✅ Demo binary target created (classification): 762 samples
#    - Class 0 (not at-risk): 536 students (70.3%)
#    - Class 1 (at-risk): 226 students (29.7%)
#
# ✅ Demo continuous target created (regression): 762 samples
#    - Mean: 3.011
#    - Std: 0.710
#    - Range: [0.683, 4.000]
#
# ==================================================
# 🚨 IMPORTANT: Replace the above with your actual target variable!
#    Example: y_actual = df['your_target_column_name']
# ==================================================

# %%
print("🟢 MODEL 2: LINEAR REGRESSION")
print("=" * 80)

# Split data for regression
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_processed, y_continuous, test_size=0.2, random_state=42
)

print(f"Training set: {X_train_reg.shape[0]} samples")
print(f"Test set: {X_test_reg.shape[0]} samples")
print(f"Features: {X_train_reg.shape[1]}")

# Train Linear Regression
print(f"\n🔄 Training Linear Regression...")
linear_model = LinearRegression()
linear_model.fit(X_train_reg, y_train_reg)

# Make predictions
y_pred_linear = linear_model.predict(X_test_reg)

# Evaluate model
mse_linear = mean_squared_error(y_test_reg, y_pred_linear)
rmse_linear = np.sqrt(mse_linear)
r2_linear = r2_score(y_test_reg, y_pred_linear)

print(f"✅ Linear Regression trained successfully!")
print(f"\n📊 LINEAR REGRESSION RESULTS:")
print(f"   Mean Squared Error (MSE): {mse_linear:.4f}")
print(f"   Root Mean Squared Error (RMSE): {rmse_linear:.4f}")
print(f"   R² Score: {r2_linear:.4f}")
print(f"   Mean Absolute Error: {np.mean(np.abs(y_test_reg - y_pred_linear)):.4f}")

# Feature importance (coefficients)
feature_importance_linear = pd.DataFrame({
    'feature': columns_to_check,
    'coefficient': linear_model.coef_,
    'abs_coefficient': np.abs(linear_model.coef_)
}).sort_values('abs_coefficient', ascending=False)

print(f"\n🔍 TOP 10 MOST IMPORTANT FEATURES (by coefficient magnitude):")
print("-" * 60)
for i, row in feature_importance_linear.head(10).iterrows():
    print(f"{row.name+1:2d}. {row['coefficient']:8.4f} | {row['feature']}")

# Create a simple residuals plot
print(f"\n📈 PREDICTION vs ACTUAL SUMMARY:")
print(f"   Actual range: [{np.min(y_test_reg):.3f}, {np.max(y_test_reg):.3f}]")
print(f"   Predicted range: [{np.min(y_pred_linear):.3f}, {np.max(y_pred_linear):.3f}]")
print(f"   Residuals mean: {np.mean(y_test_reg - y_pred_linear):.6f}")
print(f"   Residuals std: {np.std(y_test_reg - y_pred_linear):.4f}")

# Store results
linear_results = {
    'model': linear_model,
    'mse': mse_linear,
    'rmse': rmse_linear,
    'r2': r2_linear,
    'predictions': y_pred_linear,
    'feature_importance': feature_importance_linear
}
# Out:
# 🟢 MODEL 2: LINEAR REGRESSION
# ================================================================================
# Training set: 609 samples
# Test set: 153 samples
# Features: 24
#
# 🔄 Training Linear Regression...
# ✅ Linear Regression trained successfully!
#
# 📊 LINEAR REGRESSION RESULTS:
#    Mean Squared Error (MSE): 0.5104
#    Root Mean Squared Error (RMSE): 0.7144
#    R² Score: -0.0460
#    Mean Absolute Error: 0.5872
#
# 🔍 TOP 10 MOST IMPORTANT FEATURES (by coefficient magnitude):
# ------------------------------------------------------------
# 10.   0.1033 | Participated in undergraduate research
#  9.  -0.0918 | Participated in an internship on campus
# 11.  -0.0681 | How would you rate your mental health during the last 30 days?
#  8.  -0.0641 | Participated in an internship off campus
#  5.  -0.0581 | how confident are you in preparing a nutritious, healthy meal for yourself?
# 16.  -0.0506 | I have submitted a room switch request due to a roommate conflict
#  4.  -0.0486 | Eat alone
# 22.   0.0453 | In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice
# 18.   0.0393 | I seek assistance from my student leader (RA or CA)
# 13.  -0.0283 | I avoid conflict or confrontation, so I don't address the issue.
#
# 📈 PREDICTION vs ACTUAL SUMMARY:
#    Actual range: [0.957, 4.000]
#    Predicted range: [2.625, 3.454]
#    Residuals mean: -0.058124
#    Residuals std: 0.7120

# %%
# Model 1: Logistic Regression (Sigmoid) for Classification
print("🔵 MODEL 1: LOGISTIC REGRESSION (SIGMOID)")
print("=" * 80)

# Split data for classification
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(
    X_processed, y_binary, test_size=0.2, random_state=42, stratify=y_binary
)

print(f"Training set: {X_train_clf.shape[0]} samples")
print(f"Test set: {X_test_clf.shape[0]} samples")
print(f"Features: {X_train_clf.shape[1]}")

# Train Logistic Regression
print(f"\n🔄 Training Logistic Regression...")
logistic_model = LogisticRegression(random_state=42, max_iter=1000)
logistic_model.fit(X_train_clf, y_train_clf)

# Make predictions
y_pred_logistic = logistic_model.predict(X_test_clf)
y_prob_logistic = logistic_model.predict_proba(X_test_clf)[:, 1]

# Evaluate model
accuracy_logistic = accuracy_score(y_test_clf, y_pred_logistic)
print(f"✅ Logistic Regression trained successfully!")
print(f"\n📊 LOGISTIC REGRESSION RESULTS:")
print(f"   Accuracy: {accuracy_logistic:.4f}")

print(f"\n📈 Classification Report:")
print(classification_report(y_test_clf, y_pred_logistic))

print(f"\n🎯 Confusion Matrix:")
cm_logistic = confusion_matrix(y_test_clf, y_pred_logistic)
print(cm_logistic)

# Feature importance (coefficients)
feature_importance_logistic = pd.DataFrame({
    'feature': columns_to_check,
    'coefficient': logistic_model.coef_[0],
    'abs_coefficient': np.abs(logistic_model.coef_[0])
}).sort_values('abs_coefficient', ascending=False)

print(f"\n🔍 TOP 10 MOST IMPORTANT FEATURES (by coefficient magnitude):")
print("-" * 60)
for i, row in feature_importance_logistic.head(10).iterrows():
    print(f"{row.name+1:2d}. {row['coefficient']:8.4f} | {row['feature']}")

# Store results
logistic_results = {
    'model': logistic_model,
    'accuracy': accuracy_logistic,
    'predictions': y_pred_logistic,
    'probabilities': y_prob_logistic,
    'feature_importance': feature_importance_logistic
}
# Out:
# 🔵 MODEL 1: LOGISTIC REGRESSION (SIGMOID)
# ================================================================================
# Training set: 609 samples
# Test set: 153 samples
# Features: 24
#
# 🔄 Training Logistic Regression...
# ✅ Logistic Regression trained successfully!
#
# 📊 LOGISTIC REGRESSION RESULTS:
#    Accuracy: 0.7124
#
# 📈 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83       108
#            1       0.60      0.07      0.12        45
#
#     accuracy                           0.71       153
#    macro avg       0.66      0.52      0.47       153
# weighted avg       0.68      0.71      0.62       153
#
#
# 🎯 Confusion Matrix:
# [[106   2]
#  [ 42   3]]
#
# 🔍 TOP 10 MOST IMPORTANT FEATURES (by coefficient magnitude):
# ------------------------------------------------------------
#  6.   0.2707 | Worked a job on campus
# 11.  -0.2083 | How would you rate your mental health during the last 30 days?
# 10.   0.1844 | Participated in undergraduate research
#  1.   0.1741 | Eat at an on campus eatery (Food trucks, restaurants, food court)
# 22.  -0.1615 | In the last 30 days, how would you describe your relationship with your roommate(s)? - Selected Choice
#  8.  -0.1433 | Participated in an internship off campus
# 23.   0.1392 | How many total people live in your suite or apartment unit?
# 21.   0.1364 | I initiate open communication and discussion
# 17.  -0.1266 | I seek assistance from my residence hall coordinator (RHC)
# 13.  -0.1254 | I avoid conflict or confrontation, so I don't address the issue.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# Fit a simple neural network (sigmoid neuron: single hidden layer, logistic activation)
mlp = MLPClassifier(hidden_layer_sizes=(1,), activation='logistic', max_iter=1000, random_state=42)
mlp.fit(X_train, y_train)

# Predict on the test set
y_pred_mlp = mlp.predict(X_test)

# Evaluate the model
mlp_accuracy = accuracy_score(y_test, y_pred_mlp)
print(f"Sigmoid Neuron Model Accuracy: {mlp_accuracy:.2f}")
print("Classification Report:")
print(classification_report(y_test, y_pred_mlp))

# Show actual vs predicted values
mlp_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_mlp})
print(mlp_results.head(10))
# Out:
# Sigmoid Neuron Model Accuracy: 0.57
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.00      0.00      0.00        20
#            2       0.54      1.00      0.70        74
#            3       0.00      0.00      0.00        40
#            4       0.87      0.87      0.87        15
#            5       0.00      0.00      0.00         3
#
#     accuracy                           0.57       153
#    macro avg       0.23      0.31      0.26       153
# weighted avg       0.34      0.57      0.42       153
#
#    Actual  Predicted
# 0       2          2
# 1       3          2
# 2       2          2
# 3       5          4
# 4       2          2
# 5       4          4
# 6       1          2
# 7       3          2
# 8       4          4
# 9       2          2
# /home/ec2-user/csu-summer-camp-data/.venv/lib64/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/ec2-user/csu-summer-camp-data/.venv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/csu-summer-camp-data/.venv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ec2-user/csu-summer-camp-data/.venv/lib64/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
